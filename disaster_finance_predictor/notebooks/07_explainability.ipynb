# %% [markdown]
# # 07 · Explainability (SHAP)
#
# Attribution for the fitted models. Read this stage with the collinearity diagnostics from
# stage 03 in mind: where features correlate above 0.95, SHAP splits credit between them
# arbitrarily, so individual rankings inside those blocks are not identifiable even though
# the block totals are.

# %%
import sys
from pathlib import Path

sys.path.insert(0, str(Path.cwd() if (Path.cwd() / "_shared.py").exists() else Path.cwd() / "notebooks"))
from _shared import *  # noqa: F401,F403  paths, artifact cache, target bounds

from src.evaluation import figures as fx
fx.apply_thesis_style()

print("stage inputs available in the artifact cache:")
print(artifact_status().to_string(index=False) if len(artifact_status()) else "  (none yet)")

dataset = load_frame("dataset")
spec = load_json("feature_spec")
FEATURE_COLS, TARGET_COLS = spec["FEATURE_COLS"], spec["TARGET_COLS"]
X = dataset[FEATURE_COLS].fillna(0.0)
y = dataset[TARGET_COLS].copy()
selected_features = load_object("selected_features")
final_rf_models = load_object("final_rf_models")
rf_y1 = final_rf_models[TARGET_COLS[0]]  # refit on all real rows in stage 04
print(f"loaded fitted models for: {sorted(final_rf_models)}")
# Out:
# stage inputs available in the artifact cache:
#               artifact               written_utc rows                                                                                                                                                         note
# classification_summary 2026-09-11T05:03:17+00:00   16                                                                                                            Pre-registered binary labels, pooled out-of-fold.
#     conformal_coverage 2026-09-11T05:05:08+00:00    6                                                                                                               Model vs marginal interval coverage and width.
#                dataset 2026-09-11T04:05:50+00:00   74                                                                                                                            74 in-scope events x 54 features.
#              disasters 2026-09-11T04:04:49+00:00   86                                                                                                       Raw EM-DAT export, all records before scope filtering.
#        final_rf_models 2026-09-11T04:53:55+00:00                                                                                             RandomForest refit on all real rows per target, for SHAP in stage 07.
#           hurdle_table 2026-09-11T05:03:51+00:00    4                                                                                                                     Y3 hurdle vs single-stage vs both nulls.
#               in_scope 2026-09-11T04:06:08+00:00   74                                                                                                                     EM-DAT events inside the archive window.
#                  macro 2026-09-11T04:04:58+00:00   26                                                                                                         World Bank annual series, publication-lag corrected.
#                 market 2026-09-11T04:04:40+00:00 6365                                                                                                     Daily ASPI close + summed market volume, forward-filled.
#           market_feats 2026-09-11T04:05:59+00:00 6365                                                                                                                            Engineered daily market features.
#      results_ablations 2026-09-11T04:53:37+00:00                                                                                                       Split-geometry (20/5/5) and feature-count (K=10) ablations.
# results_classification 2026-09-11T05:03:42+00:00                                                                                         Pre-registered binary labels and the Y3 hurdle model, pooled out-of-fold.
#     results_regression 2026-09-11T04:53:28+00:00      Out-of-fold predictions, 4-fold walk-forward, models: ['ensemble', 'mlp', 'naive_train_mean', 'naive_zero', 'random_forest', 'ridge', 'stacked', 'xgboost'].
#         results_sector 2026-09-11T03:10:45+00:00                                                                                                                             Sector-panel out-of-fold predictions.
#           sector_panel 2026-09-11T03:09:33+00:00 1253                                                                                                                 One row per (event, sector), Y1 and Y3 only.
#   sector_panel_summary 2026-09-11T03:09:54+00:00    8                                                                                                                           Sector-panel walk-forward results.
#   sector_panel_verdict 2026-09-11T03:10:13+00:00    8                                                                                                                          Event-clustered bootstrap verdicts.
#      sector_per_sector 2026-09-11T03:10:29+00:00   20                                                                                                                                 Out-of-fold error by sector.
#      selected_features 2026-09-11T04:53:46+00:00                                                                                                                      Top-K features chosen per target, last fold.
#                  sp500 2026-09-11T04:05:06+00:00 6537                                                                                                                    S&P 500 daily log return, global control.
#                 splits 2026-09-11T04:06:17+00:00                                                                                                  4 chronological walk-forward folds (train/test/step = 30/10/10).
#          verdict_table 2026-09-11T05:04:45+00:00   36                                                                                                Stage-0 predictability verdicts, bootstrap + Diebold-Mariano.
# loaded fitted models for: ['Y1_aspi_log_return', 'Y2_abnormal_volume', 'Y3_recovery_days']

# %% [markdown]
# ## 11. Explainability (SHAP)
#
# Thesis §3.8.2 / blueprint Step 9 agree on this. TreeSHAP applied to the Random Forest's Y1 (ASPI) estimator, both globally (what drives predictions across all events) and locally (one real historical event, not Ditwah — it isn't in the modeled set, see §5).

# %%
import shap

# Y1's own selected feature set from the last walk-forward fold (\u00a79's
# per-target feature selection) -- SHAP must be computed on exactly the
# columns rf_y1 was actually trained on. Explained over the real 64 events
# only (X, not any SMOGN output) -- SMOGN's synthetic rows exist only inside
# each fold's training step now, never as a standing dataset to explain.
y1_features = selected_features[TARGET_COLS[0]]
X_y1 = X[y1_features]

explainer = shap.TreeExplainer(rf_y1)
shap_values = explainer.shap_values(X_y1)

shap.summary_plot(shap_values, X_y1, show=False)

# %%
import matplotlib.pyplot as plt
plt.tight_layout()
plt.show()

# %%
# Local explanation for one real, modeled event (largest ASPI drop in the training set)
worst_idx = int(y["Y1_aspi_log_return"].idxmin())
print("Explaining event row:", worst_idx, "Y1 =", y.loc[worst_idx, "Y1_aspi_log_return"])

explanation = shap.Explanation(
    values=shap_values[worst_idx], base_values=explainer.expected_value,
    data=X_y1.iloc[worst_idx], feature_names=X_y1.columns.tolist(),
)
shap.plots.waterfall(explanation, show=False)
plt.tight_layout()
plt.show()
# Out:
# Explaining event row: 8 Y1 = -0.07533808664469309
